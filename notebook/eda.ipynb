# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# CSV file semicolon (;) separated hai
df = pd.read_csv("../data/e-shop clothing 2008.csv", sep=";")
print("\n📌 Dataset Loaded Successfully")
# Out:
# 📌 Dataset Loaded Successfully

# %%
# Dataset Shape & Columns
print("\n📊 Dataset Shape (Rows, Columns):")
print(df.shape)

print("\n📋 Column Names:")
print(df.columns.tolist())
# Out:
# 📊 Dataset Shape (Rows, Columns):
# (165474, 14)
#
# 📋 Column Names:
# ['year', 'month', 'day', 'order', 'country', 'session ID', 'page 1 (main category)', 'page 2 (clothing model)', 'colour', 'location', 'model photography', 'price', 'price 2', 'page']

# %%
# Missing Values Check
print("\n❓ Missing Values Count:")
print(df.isnull().sum())
# Out:
# ❓ Missing Values Count:
# year                       0
# month                      0
# day                        0
# order                      0
# country                    0
# session ID                 0
# page 1 (main category)     0
# page 2 (clothing model)    0
# colour                     0
# location                   0
# model photography          0
# price                      0
# price 2                    0
# page                       0
# dtype: int64

# %%
# Conversion Column Banana
# Rule: Agar user page 4 ya 5 tak gaya = Conversion
df["conversion"] = df["page"].apply(lambda x: 1 if x >= 4 else 0)

print("\n✅ Conversion Column Created")

# Conversion distribution
print("\n📈 Conversion Value Counts:")
print(df["conversion"].value_counts())

# Conversion rate
conversion_rate = (df["conversion"].sum() / len(df)) * 100
print(f"\n📊 Conversion Rate: {conversion_rate:.2f}%")
# Out:
# ✅ Conversion Column Created
#
# 📈 Conversion Value Counts:
# conversion
# 0    153790
# 1     11684
# Name: count, dtype: int64
#
# 📊 Conversion Rate: 7.06%

# %%
# Correlation analysis with conversion
correlation_df = pd.DataFrame(df.corr()["conversion"])
correlation_df.columns = ["correlation"]
correlation_df = correlation_df.sort_values("correlation", ascending=False)

print("\n📊 Feature Correlation with Conversion:")
print(correlation_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Correlation analysis with conversion
# ----> 2 correlation_df = pd.DataFrame(df.corr()["conversion"])
#       3 correlation_df.columns = ["correlation"]
#       4 correlation_df = correlation_df.sort_values("correlation", ascending=False)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:1713, in BlockManager.as_array(self, dtype, copy, na_value)
#    1711         arr.flags.writeable = False
#    1712 else:
# -> 1713     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1714     # The underlying data was copied within _interleave, so no need
#    1715     # to further copy if copy=True or setting na_value
#    1717 if na_value is lib.no_default:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\internals\managers.py:1772, in BlockManager._interleave(self, dtype, na_value)
#    1770     else:
#    1771         arr = blk.get_values(dtype)
# -> 1772     result[rl.indexer] = arr
#    1773     itemmask[rl.indexer] = 1
#    1775 if not itemmask.all():
#
# ValueError: could not convert string to float: 'A13'

# %%
# Summary and recommendations
print("\n🎯 EDA Completed Successfully")
print("\n📝 Recommendations for Model Training:")
print("1. 'page' feature has highest correlation (0.63)")
print("2. 'order' feature has moderate correlation (0.03)")
print("3. Consider using: page, order, price, price 2, month, day, country")
print("4. Remove: year (constant value), session ID (too many unique values)")
# Out:
# 🎯 EDA Completed Successfully
#
# 📝 Recommendations for Model Training:
# 1. 'page' feature has highest correlation (0.63)
# 2. 'order' feature has moderate correlation (0.03)
# 3. Consider using: page, order, price, price 2, month, day, country
# 4. Remove: year (constant value), session ID (too many unique values)
